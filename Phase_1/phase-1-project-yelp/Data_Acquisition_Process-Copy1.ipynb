# %% [markdown]
# # Getting Your Data From Yelp!

# %% [markdown]
# In order to make sure you are on track to completing the project, you will complete this workbook first. Below are steps that you need to take in order to make sure you have your data from yelp and are ready to analyze it. Your cohort lead will review this workbook with you the Wednesday before your project is due.

# %% [markdown]
# ## Part 1 - Understanding your data and question
#
# You will be pulling data from the Yelp API to complete your analysis. The api, however, provides you with a lot of information that will not be pertinent to your analysis. YOu will pull data from the api and parse through it to keep only the data that you will need. In order to help you identify that information,look at the API documentation and understand what data the api will provide you.
#
# Identify which data fields you will want to keep for your analysis.
#
# https://www.yelp.com/developers/documentation/v3/get_started

# %% [markdown]
# ___

# %% [markdown]
# ## Part 2 - Create ETL pipeline for the business data from the API
#
# Now that you know what data you need from the API, you want to write code that will execute a api call, parse those results and then insert the results into the DB.
#
# It is helpful to break this up into three different functions (*api call, parse results, and insert into DB*) and then you can write a function/script that pull the other three functions together.
#
# Let's first do this for the Business endpoint.

# %% [markdown]
# - Write a function to make a call to the yelp API

# %%
import pandas as pd
import requests
import json

# %%
with open('../ds-apis-nbz32-main/.secrets/creds.json') as f:
    creds = json.load(f)

# %%
api_key = creds['key']
term = 'bike'
location = 'Manhattan NY'
SEARCH_LIMIT = 50
url_params = {
        'term': term.replace(' ', '+'),
        'location': location.replace(' ', '+'),
        'limit': SEARCH_LIMIT,
        'offset': 0 
    }

# %%
def yelp_call(url_params, api_key):
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {'Authorization': 'Bearer ' + api_key}
    
    data = requests.get(url, headers = headers, params = url_params)
    return data

# %%
results = yelp_call(url_params, api_key)

# %% [markdown]
# - Write a function to parse the API response so that you can easily insert the data in to the DB

# %%
def parse_results(results):
    # your code to parse the result to make them easier to insert into the DB
    results = results.json()['businesses']
    parsed_data = []
    for business in results:
        if 'price' not in business:
            biz_info = (business['id'], business['name'], business['is_closed'],
                business['review_count'], business['rating'], 'NaN',
                business['location']['zip_code'])
            parsed_data.append(biz_info)
        else:
            biz_info = (business['id'], business['name'], business['is_closed'],
                business['review_count'], business['rating'], business['price'],
                business['location']['zip_code'])
            parsed_data.append(biz_info)
    return parsed_data

# %%
t_ = pd.DataFrame(parse_results(results), columns = ('ID', 'Name', 'Is_Closed',
                                           'Review_Count', 'Rating', 'Price',
                                           'Zip_Code'))
t_
# Out:
#                         ID                          Name  Is_Closed  \
# 0   Y2vbaQdhP6ALJrhGYpkFQg            Kickstand Bicycles      False
# 1   n4YHCDxWp07DicFxOcLzlw                  Bicycles NYC      False
# 2   XnBflxEeUp0C-MefpSSTMg                Liberty Cycles      False
# 3   HdEwDk5wyjaLIvuhG9Awrw             New Bo Bo Bicycle      False
# 4   wN6qVSygUdRPWblnyqW3mQ              Master Bike Shop      False
# 5   gyd5P7rsmQJNVi2iefqxBQ               Bicycle Habitat      False
# 6   fp-zSkRVDQtqQqOjgQrm3Q            Conrad's Bike Shop      False
# 7   6-8mPcAw_E6nw8iq5rLnCg               Sid's Bikes NYC      False
# 8   Lop47NYZAv6i9ooB8UfkLA                      NYC Velo      False
# 9   hiqIh1pCiQFKI4jTPbJ47g  Trek Bicycle Upper East Side      False
# 10  QrmlBi1daUgPYEzTO7EUZw   Trek Bicycle Hell's Kitchen      False
# 11  DpAO4gzlnHI2VR4T4asN3w                 City Bicycles      False
# 12  -4qS1PjthLyXIM8L3MN-HA                    CC Cyclery      False
# 13  00rrqw4O0Flfatd0VV6QAg          Larry's Freewheeling      False
# 14  4LQnOyQDxvcPZqBVx5w2SA                      JS Cycle      False
# 15  LznPvq03PyXc1Zzj_RhI8g        Roy's Sheepshead Cycle      False
# 16  j0TlhwjiY1xcwGajXR3ApQ                      NYC VELO      False
# 17  AA7U-jkHEWH3nvwncDsQxw       Waterfront Bicycle Shop      False
# 18  u3DShnHnbCCe2LytZj4yWw              Rapha - New York      False
# 19  LCsvHORwlDbJSpwGxTRBkw          Al's Cycle Solutions      False
# 20  DOFebHYJg_UQtM1sBO9x9Q                    Gotham Fix      False
# 21  bsbOm3HN8Dw2WsBoiW8csA   Strictly Cycling Collective      False
# 22  W3aYaHrU03QQ7XW7IcLUcw    Spokesman Cycles East Side      False
# 23  serRgVkaNLDNZ2GNi1HNqQ             Enoch's Bike Shop      False
# 24  tBGchHdYeek7EmpG6lr8DA               Toga Bikes Shop      False
# 25  nKrWiY1r3CvCrXyrHRbBKw             Priority Bicycles      False
# 26  Dzr4xHHtMixMe3umIjgasA             Champion Bicycles      False
# 27  SPmteHwY_fOu619EnzlgWQ                Echelon Cycles      False
# 28  um2BpHBOE95F23gLzgXXoQ                 Bike New York      False
# 29  E11jtpLW6c4eKkTJWcD1XA        Bfold Folding Bicycles      False
# 30  JvLN_NaWbJDUu6YsubFdIw                    BikefixNYC      False
# 31  6x5bQTCQR8FNv6iPWjtU9A        Central Park Rent Bike      False
# 32  b0PPbzfNY6dgghfDt7ld2w             Frank's Bike Shop      False
# 33  Mh4ZWZMgahAI_1xu-0VXWw              Silk Road Cycles      False
# 34  8s89Dj61Ly-pD3VuXix_gA         Innovations Bike Shop      False
# 35  Vz2cj7e9Xhazb3zERAU9mw                      Dah Shop      False
# 36  AWLXZPJbKnh_2vWuFvMbpA                     B's Bikes      False
# 37  euqD9XFALQWallgqBydW2Q                 Flo On Wheels      False
# 38  jtZZP2PXsg-uIbvH-f6xdA         Kween Kargo Bike Shop      False
# 39  9dSmioBfQ_We564SCRzs4Q          Trek Bicycle Chelsea      False
# 40  jUY98iDWOHr43OrPye_EfQ         Eduardos Bicycle Shop      False
# 41  WM_Yx1Tf-c9g-mQ0BX8rrw                 Talent Cycles      False
# 42  O2l_Ne68cmg03Mp6YM6tdw                The Bike Truck      False
# 43  JZnkYuesxHla72hRnrmnsw         Eddie's Bicycles Shop      False
# 44  8z9lEIKr-_uDASFqPA5Vfg                Off The Bridge      False
# 45  xs1FuKHvYl9V1ZKUMDBz5g             Brompton Junction      False
# 46  r1U_JNxMPTVk77SIpQdBww                     GoGo Gone      False
# 47  jTKhAiUlEJnCiNKrVl9lYw         Heavy Metal Bike Shop      False
# 48  2CEJIlumIGEZ_mImDVPPzQ                 Jersey Cycles      False
# 49  sR6xqwCJEwHnPN6pIavysQ               Joulvert ebikes      False
#
#     Review_Count  Rating Price Zip_Code
# 0            161     5.0    $$    10017
# 1            125     4.0   $$$    10075
# 2            170     4.5     $    10019
# 3            116     5.0     $    10013
# 4            144     4.0    $$    10023
# 5            266     3.5    $$    10011
# 6             38     4.5   $$$    10017
# 7            149     3.5   $$$    10011
# 8            180     4.0    $$    10003
# 9             16     4.5   NaN    10128
# 10             6     4.5   NaN    10036
# 11            48     4.0    $$    10018
# 12            42     5.0    $$    10009
# 13           129     4.5    $$    10026
# 14            66     4.5     $    10026
# 15           194     4.5    $$    11235
# 16            26     4.0   $$$    10036
# 17            85     4.5     $    10014
# 18            30     4.0   $$$    10012
# 19            91     4.0    $$    10036
# 20            12     5.0   NaN    10007
# 21             4     5.0   NaN    10001
# 22            32     2.5    $$    10022
# 23            44     4.0     $    10018
# 24           182     3.0   $$$    10023
# 25            12     5.0    $$    10013
# 26            46     4.0     $    10025
# 27            88     3.5    $$    10014
# 28            25     4.5     $    10115
# 29            90     5.0   $$$    10003
# 30             9     4.0   NaN    10009
# 31            88     3.5   NaN    10019
# 32            89     4.0     $    10002
# 33           102     5.0    $$    11222
# 34            40     4.5    $$    10025
# 35            50     4.5     $    10002
# 36           242     4.5    $$    11222
# 37            83     4.5    $$    07030
# 38            32     4.5     $    11222
# 39             9     3.5   NaN    10011
# 40            11     4.0   NaN    10029
# 41            70     4.0    $$    10031
# 42            47     5.0    $$    11206
# 43            31     3.5    $$    10024
# 44            69     5.0     $    10002
# 45            11     5.0   NaN    10014
# 46            30     4.5    $$    10002
# 47            38     4.0     $    10029
# 48            53     4.5    $$    07307
# 49            11     3.0   NaN    10013

# %% [markdown]
# - Write a function to take your parsed data and add it to the csv file where you will store all of your results.

# %%
t_.to_csv(index=False)

# %%
def df_safe(csv filepath, parsed results):
    # your code to open the csv file, concat the current data, and save the data.

# %% [markdown]
# - Write a script that combines the three functions above into a single process.

# %% [markdown]
# While it will take some experimentation to write the functions above, once you get them working it will be best to put them in a `.py` file and then import the functions to use in a script

# %%
from helper_funcs import *

# %%
# create a variable  to keep track of which result you are in. 
cur = 0

#set up a while loop to go through and grab the result 
while cur < num and cur < 1000:
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = cur
    #make your API call with the new offset number
    results = yelp_call(url_params, api_key)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    
    # use your function to insert your parsed results into the db
    df_save(parsed_results)
    #increment the counter by 50 to move on to the next results
    cur += 20

# %% [markdown]
# ___

# %% [markdown]
# ## Part 3 -  Create ETL pipeline for the restaurant review data from the API
#
# You've done this for the Businesses, now you need to do this for reviews. You will follow the same process, but your functions will be specific to reviews. Above you ahve a model of the functions you will need to write, and how to pull them together in one script. For this part, you ahve the process below

# %% [markdown]
# - In order to pull the reveiws, you will need the business ids. So your first step will be to get all of the business ids from your businesses csv.

# %% [markdown]
# - Write a function that takes a business id and makes a call to the API for reivews

# %% [markdown]
# - Write a function to parse out the relevant information from the reviews

# %% [markdown]
# - Write a function to save the parse data into a csv file containing all of the reviews.

# %% [markdown]
# - Combine the functions above into a single script

# %% [markdown]
# ___

# %% [markdown]
# ## Part 4 -  Using python and pandas, write code to answer the questions below.
#
#
# - Which are the 5 most reviewed businesses in your dataset?
# - What is the highest rating recieved in your data set and how many businesses have that rating?
# - What percentage of businesses have a rating greater than or  4.5?
# - What percentage of businesses have a rating less than 3?
# - What percentage of your businesseshave a price label of one dollar sign? Two dollar signs? Three dollar signs? No dollar signs?
# - Return the text of the reviews for the most reviewed business.
# - Find the highest rated business and return text of the most recent review. If multiple business have the same rating, select the business with the most reviews.
# - Find the lowest rated business and return text of the most recent review.  If multiple business have the same rating, select the business with the least reviews.

# %% [markdown]
# ___

# %% [markdown]
# # Reference help

# %% [markdown]
# ###  Pagination
#
# Returning to the Yelp API, the [documentation](https://www.yelp.com/developers/documentation/v3/business_search) also provides us details regarding the API limits. These often include details about the number of requests a user is allowed to make within a specified time limit and the maximum number of results to be returned. In this case, we are told that any request has a maximum of 50 results per request and defaults to 20. Furthermore, any search will be limited to a total of 1000 results. To retrieve all 1000 of these results, we would have to page through the results piece by piece, retriving 50 at a time. Processes such as these are often refered to as pagination.
#
# Now that you have an initial response, you can examine the contents of the json container. For example, you might start with ```response.json().keys()```. Here, you'll see a key for `'total'`, which tells you the full number of matching results given your query parameters. Write a loop (or ideally a function) which then makes successive API calls using the offset parameter to retrieve all of the results (or 5000 for a particularly large result set) for the original query. As you do this, be mindful of how you store the data.
#
# **Note: be mindful of the API rate limits. You can only make 5000 requests per day, and APIs can make requests too fast. Start prototyping small before running a loop that could be faulty. You can also use time.sleep(n) to add delays. For more details see https://www.yelp.com/developers/documentation/v3/rate_limiting.**

# %% [markdown]
# ***Below is sample code that you can use to help you deal with the pagination parameter and bring all of the functions together.***
#
#
# ***Also, something might cause your code to break while it is running. You don't want to constantly repull the same data when this happens, so you should insert the data into the database as you call and parse it, not after you have all of the data***

# %%
# create a variable  to keep track of which result you are in. 
cur = 0

#set up a while loop to go through and grab the result 
while cur < num and cur < 1000:
    #set the offset parameter to be where you currently are in the results 
    url_params['offset'] = cur
    #make your API call with the new offset number
    results = yelp_call(url_params, api_key)
    
    #after you get your results you can now use your function to parse those results
    parsed_results = parse_results(results)
    
    # use your function to insert your parsed results into the db
    db_insert(parsed_results)
    #increment the counter by 50 to move on to the next results
    cur += 20
